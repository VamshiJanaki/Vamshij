# %% [markdown]
# - two blocks
# - one is try block another one is expect block
# -original code will write in try block
# - if any error is there in original code it will catch in excepy block
# - **try and except** concept is used to handle error without the crash the python code

# %%
try:
     virat
except Exception as e:
    print(e)
# Out:
# name 'virat' is not defined

# %%
try:
    naresh
except Exception as e:
    print(e)
# Out:
# name 'naresh' is not defined

# %%
try:
    naresh
except Exception as e:
    print(e)
    print('hai')
# Out:
# name 'naresh' is not defined
# hai

# %%
try:
    a=10
    print(a)
    b=20
    print(b)
    c=a+bb
except Exception as e:
    print('hai')
    print('hello')
# Out:
# 10
# 20
# hai
# hello

# %%
try:
    100/0
except Exception as e:
    print(e)
# Out:
# division by zero

# %%
try:
    100+'apple'
except Exception as e:
    print(e)
# Out:
# unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# **finally block**

# %%
try:
    print('i have make a good tea')
except Exception as e:
    print(e)
finally:
    print('okay! cleaan the mess')
# Out:
# i have make a good tea
# okay! cleaan the mess

# %%
try:
    10/0
except Exception as e:
    print(e)
    print('i have make good tea')
finally:
    print('okay! clean the mess')
# Out:
# division by zero
# i have make good tea
# okay! clean the mess
