# %%
# i want to say hello 
# cond: if i know you 

print('hello')
# Out:
# hello

# %%
if === at the end : == next line start with gap

indentation

# %%
if <condition>:
    #code1
    #code2
    
    #code3

# %%
# i will want to print the hello with condition

# %%
if 10>0:
    print('hello')

# %%
a=10
b=30
if a<b:
    print('hello')
else:
    print('heo')
# Out:
# hello

# %%
if 10>0:
    print('true')
# Out:
# true

# %%
if True :
    print('hai')
# Out:
# hai

# %%
if False:
    print('hey')

# %%
print('hai')
if True:
    print('good morning')
    if True:
        print('good eve')
        print('good night')
print('bye')
# Out:
# hai
# good morning
# good eve
# good night
# bye

# %%
print('hai')
if True:
    print('good morning')
    
    if False:
        print('good eve')
        print('good night')
print('bye')
# Out:
# hai
# good morning
# bye

# %% [markdown]
# **if&else**

# %%
- if will be activated when condition is True

- otherwise else will be activate

-only if need condition, else does not need any condition

# %%
if<cond>:
    <write the code>
else:
    <write the code>

# %%
if True:
    print('hai')
else:
    print('bye')
# Out:
# hai

# %%
if False:
    print('hai')
else:
    print('bye')
# Out:
# bye

# %%
print('1')
print('2')
if True:
    print('hai')
else:
    print('bye')
    print('done')
# Out:
# 1
# 2
# hai

# %%
print('1')
print('2')
if True:
    print('hai')
print('why are you in middle')    
else:
    print('bye')
    print('done')
# Out:
#   Cell In[12], line 6
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
if True:
    print('hai')

    if True:
        print('hello')
    else:
        print('bye')
else:
    print('done')
# Out:
# hai
# hello

# %%
if True:
    print('hi im the father')

    if True:
        print('hi im the first son')
        if True:
            print('hi im the sec son')
        else:
            print('hi im the first son mother')
else:
    print('im the sec son mother')
# Out:
# hi im the father
# hi im the first son
# hi im the sec son

# %%
if True:
    print('yogi')
    
    if False:
        print('radha prazsad')
        if True:
            print('gopi')
        else:
            print('rohith')
else:
    print('yash')
# Out:
# yogi

# %%
if True:
    print('hai')

    if True:
        print('hello')

        if True:
            print('hi')
        else:
            print('hi1')
    else:
        print('hello2')
        
else:
    print('hai3')
# Out:
# hai
# hello
# hi

# %%
Even and odd
ask the user enter a value 
print if the number is even
otherwise print odd

idea:
# Out:
#   Cell In[19], line 2
#     ask the user enter a value
#         ^
# SyntaxError: invalid syntax

# %%
num=eval(input("enter the number:"))
if num%2==0:
    print('even')
else:
    print('odd')
# Out:
# enter the number: 11
# odd

# %%
inst_name=input("enter the institute name:")
if inst_name=='NareshIT':
    print('good')

else:
    print('katam')
# Out:
# enter the institute name: NareshIT
# good

# %%
Inst_name=input("enter Institute:")
con=Inst_name.lower()=='NareshIT'.lower()
if con:
    print('good')
else:
    print('katam')
# Out:
# enter Institute: NareshIT
# good

# %%
n1=10
n2=20
if(n1&n2==0):
    print('won')
else:
    print('lost')
# Out:
# won

# %%
n1=eval(input("enter the num1:"))
n2=eval(input("enter the num2:"))
if n1==n2:
    print('won')
else:
    print('lost')
# Out:
# enter the num1: 5
# enter the num2: 8
# lost

# %%
import random
n1=random.randint(1,10)
n2=input("enter the num:")
if n1==n2:
    print('won')
else:
    print('lost')
# Out:
# enter the num: 2
# lost

# %%
import random
n1=random.randint(2,20)
n2=input("enter the num:")
if n1==n2:
    print('won')
else:
    print('lost')
# Out:
# enter the num: 2
# lost

# %%
import random
n1=random.randint(10,40)
n2=input("enter the num:")
if n1==n2:
    print('lost')
else:
    print('won')
# Out:
# enter the num: 10
# won

# %%
import random
n1=random.randint(40,90)
n2=input("enter the num:")
if n1==n2:
    print('won')
else:
    print('lost')
# Out:
# enter the num: 90
# lost

# %%
inst_name=input("enter a institute name:")
cours_name=input("enter a course name:")
if inst_name== 'nareshit' .lower() and cours_name=='ai'.lower():
              print("good future")
else:
              print("katam")
# Out:
# enter a institute name: nareshit
# enter a course name: ai
# good future

# %%
a=eval(input("enter the distance km:"))
if a>=25:
    charge=a*2
    print(f"the total amount is:,{charge}")
else:
    print('free ride')
# Out:
# enter the distance km: 3
# free ride

# %%
# wap 
# ask the gender
# if male charge 4 rupeesper km
# if female then
# print the free ride

# %%
gender=input("enter the gender:")
if gender.lower ()=='male':
    dist=eval(input("enter the distance:")
              if distance>=25
              charge=eval(input("enter the charge:")
              char_dist=distance-25

# %% [markdown]
# if-ellif-else
#
# - when only if is available : one answer
#
# - when if else is available : one condition two possible
#
# -

# %%
percent=eval(input("enter the percentage"))
if percent>=75:
    print('print A')
elif percent >=60:
    print('print b')
elif percent >=45:
    print('print c')
elif percent >=35:
    print('print d')
else:
    print("fail")
# Out:
# enter the percentage 56
# print c
