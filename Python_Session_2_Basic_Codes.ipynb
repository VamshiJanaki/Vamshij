# %%
# area of circle
r= 10
circle= 3.14*r*r
print(circle)
# Out:
# 314.0

# %%
# area of rectangle
h=10
b=20
area= 0.5*h*b
print(area)
# Out:
# 100.0

# %%
income = 100000
tax_per= 10
tax_amount =  (income*tax_per)/100
print(tax_amount)
# Out:
# 10000.0

# %%
salary=10000
tax_per=20
tax_amount=salary*tax_per/100
tax_amount
# Out:
# 2000.0

# %%
bill = 1000
tip_per=10
tax=bill*tip_per/100
total_bill=bill+tax
total_bill
# Out:
# 1100.0

# %%
area of circle=10
# Out:
#   Cell In[3], line 1
#     area of circle=10
#          ^
# SyntaxError: invalid syntax

# %%
area_of_circle=10

# %%
_=100

# %%
if=100
# Out:
#   Cell In[6], line 1
#     if=100
#       ^
# SyntaxError: invalid syntax

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 max(0)
#
# TypeError: 'int' object is not iterable

# %%
a=10

# %%
a
# Out:
# 10

# %%
int(10),float(10),bool(10)
# Out:
# (10, 10.0, True)

# %%
bool(10),bool(''),bool(),bool(" ")
# Out:
# (True, False, False, True)

# %%
print(int(10),
      float(10))
# Out:
# 10 10.0

# %%
int(10.6),int(.8),int(10.9)
int(10.6)
float(.8)
int(float(10.9))
# Out:
# 10

# %%
int(10.5)
# Out:
# 10

# %%
int('10.5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 int('10.5')
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
10+20
# Out:
# 30

# %%
input()
# Out:
#  100
# '100'

# %%
a=input()
b=input()
a+b
# Out:
#  10
#  20
# '1020'

# %%
a=int(input())
b=int(input())
a+b
# Out:
#  20
#  40
# 60

# %%
input('bro enter num 1:')
# Out:
# bro enter num 1: 10
# '10'

# %%
n1=int(input('enter the n1:'))
n2=int(input('enter the n2:'))
print(f'sum of {n1},{n2} is:{n1+n2}')
# Out:
# enter the n1: 40
# enter the n2: 10
# sum of 40,10 is:50

# %%
n1=int(input('enter the n1:'))
n2=int(input('enter the n2:'))
print(f'sum of {n1},{n2} is:{n1+n2}')
# Out:
# enter the n1: 10.5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 n1=int(input('enter the n1:'))
#       2 n2=int(input('enter the n2:'))
#       3 print(f'sum of {n1},{n2} is:{n1+n2}')
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
n1=float(input('enter the n1'))
n2=float(input('enter the n2'))
print(f'sum of {n1},{n2} is:{n1+n2}')
# Out:
# enter the n1 10.5
# enter the n2 10.5
# sum of 10.5,10.5 is:21.0

# %%
eval('10'),float(10)
# Out:
# (10, 10.0)

# %%
eval('10.5'),float(50)
# Out:
# (10.5, 50.0)

# %%
n1=eval(input('enter the n1'))
n2=eval(input('enter the n2'))
print(f'sum of {n1},{n2} is:{n1+n2}')
# Out:
# enter the n1 10.8
# enter the n2 10
# sum of 10.8,10 is:20.8

# %%
name=input('enter your name')
age=input('enter your age')
city=input('enter your city')
print('my name is python,i have 10 years old,i came from hyd')
print('my name is nareshit,i have 24 years old,i came from hyd')
print(f'my name is {name},i have {age} years old,i came from {city}')
# Out:
# enter your name vamshi
# enter your age 23
# enter your city nizamabad
# my name is python,i have 10 years old,i came from hyd
# my name is nareshit,i have 24 years old,i came from hyd
# my name is vamshi,i have 23 years old,i came from nizamabad
