# %%
# WAP ask the user take 3 numbers and find the avg
n1=10
n2=20
n3=30
avg=(n1+n2+n3)/3
avg
# Out:
# 20.0

# %%
n1=eval(input("enter a n1:"))
n2=eval(input("enter a n2:"))
n3=eval(input("enter a n3:"))
avg=(n1+n2+n3)/3
avg
# Out:
# enter a n1: 10
# enter a n2: 89
# enter a n3: 90
# 63.0

# %%
round(10.6789,3)
# Out:
# 10.679

# %%
round(10.6789,4)
# Out:
# 10.6789

# %%
round(10.6789,1)
# Out:
# 10.7

# %%
round(10.678956,5)
# Out:
# 10.67896

# %%
n1=eval(input("enter a n1:"))
n2=eval(input("enter a n2:"))
n3=eval(input("enter a n3:"))
avg=(n1+n2+n3)/3
avg1=round(avg,2)
print(f"the avg of {n1},{n2},{n3} is :{avg1}")
# Out:
# enter a n1: 10
# enter a n2: 50
# enter a n3: 70
# the avg of 10,50,70 is :43.33

# %%
r1=eval(input("enter the r1:"))
r2=eval(input("enter the r2:"))
r3=eval(input("enter the r3:"))
avg=(r1+r2+r3)/3
avg1=round(avg,2)
print(f"the avg of {r1},{r2},{r3} is :{avg1}")
# Out:
# enter the r1: 20
# enter the r2: 10
# enter the r3: 60
# the avg of 20,10,60 is :30.0

# %%
a=eval(input("enter the v:"))
area= (3.14) *a*a
area=round(area, 2)
print(f"the area of circle with radius {a} is :{area}")
# Out:
# enter the v: 30
# the area of circle with radius 30 is :2826.0

# %%
l = float(input("enter the length:"))
b = float(input("enter the breadth:"))
area= l*b
area= round(area,2)
print(f"the area of rectangle with {l} and {b} is :{area}")
# Out:
# enter the length: 5
# enter the breadth: 10
# the area of rectangle with 5.0 and 10.0 is :50.0

# %%
avg = 85.57891
avg1 = round(avg, 2)

print(avg1)
# Out:
# 85.58

# %%
avg = 85.67891
avg1 = round(avg, 2)

print(avg1)
# Out:
# 85.68

# %%
round(number, digits)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 round(number, digits)
#
# NameError: name 'number' is not defined

# %%
x= 12.34567
print(round(x,2))
# Out:
# 12.35

# %%
x=12.34567
print(round(x,2))
# Out:
# 12.35

# %%
x=5.698
print(round(x,2))
# Out:
# 5.7

# %%
x=13.431567
print(round(x,2))
# Out:
# 13.43

# %%
x=14.12345
print(round(x,2))
# Out:
# 14.12
