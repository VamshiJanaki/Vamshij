# %%
- logical error: we written a proper code but the logic is failed
- Syntax error : python is expecting from you to write a proper code 
- Inbuilt functions
    - print
    - type
    - sum
    - max
    - min
    - len
  - if we miss the brackets

   -  functions

   -  bound method
# Out:
#   Cell In[1], line 1
#     - logical error: we written in
#               ^
# SyntaxError: invalid syntax

# %%
a=10
float(a),str(a),bool(a)
# Out:
# (10.0, '10', True)

# %%
b=20
float(b),str(b),bool(b)
# Out:
# (20.0, '20', True)

# %%
int("10") ,float("10") ,bool("10")
# Out:
# (10, 10.0, True)

# %%
int('10')
float('10')
bool('10')
int('10.5')
bool('10.5')
float('10.5')
int('apple')
float('apple')
bool('apple')
int('0')
float('0')
bool('0')
int('')
float('')
bool('')
int(' ')
float(' ')
bool(' ')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 4
#       2 float('10')
#       3 bool('10')
# ----> 4 int('10.5')
#       5 bool('10.5')
#       6 float('10.5')
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %% [markdown]
# input

# %%
input()
# Out:
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x000002729C641E80>>

# %%
input()
# Out:
#  100
# '100'

# %%
a=10
a
# Out:
# 10

# %%
## input()
input()
# Out:
#  100
#  200
# '200'

# %%
name=input('enter your name')
age=eval(input('enter your age'))
city=input('enter city:')
print('my name is python,i have 10years old,i came from hyd')
print('my name is Nareshit,i have 24 years old,i came from hyd')
print(f'my name i{name],i have {age} years
